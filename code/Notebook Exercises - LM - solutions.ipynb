# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="4"><p><b>Exercise 1:</b> Let's look at another region: VAL. Find all neurons sending output to this region and plot them (axon end points)
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="4"><p><b>Exercise 2:</b> Pick one neuron here. Plot it in 3D with the CCF mesh. What fraction of this neuron's axonal endpoints are in our original target region of VAL? Does VAL seem to be this neuron's "primary" projection target?
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="3"><p><b>Exercise 3:</b> Find all neurons with somas in this region and plot them.
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="4"><p><b>Exercise 4:</b> Calculate the feature matrix of projection targets.
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="3"><p><b>Exercise 5:</b> Calculate the following features for all neurons: total axon length, total dendrite length and numberr of branch points.
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="3"><p><b>Exercise 6:</b> Add these 3 features to your feature matrix. Does it look different?
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
# <font size="3"><p><b>Extra Credit:</b> Cluster the cells with your choice of k with and without the extra 3 features. What do you see? Did the extra features add any information?
#
# </div>

# %% [markdown]
# <div style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; ">
#
# <h4>Extra Exercises </h4>
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# <font size="4"><p><b>Task 1.1:</b>  Find the most fine-grained brain region contained in the CCF (i.e. region at the largest depth).
#
# </div>

# %% [markdown]
# <div style="background: #DFF0D8; border-radius: 3px; padding: 10px;">
#
# <font size="4"><p><b>Task 1.2:</b>  How many brain regions are at a depth=0, 1,..., n where n is the depth value from Task 1.1.
#
# </div>
